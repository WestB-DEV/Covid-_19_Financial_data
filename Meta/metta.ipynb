# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy as st

# %%
all_df = pd.read_csv(r"C:\Users\kylem\Desktop\Bootcamp_Assignments\Group-5-bland-repo\resources\Maang stock prices\combined_file.csv")
all_df = pd.DataFrame(all_df)

# %%
#Create dataframe of the FAANG companies
value_to_remove = 'Name'
clean_df = all_df[all_df['Name'] != value_to_remove]

clean_df['Date'] = pd.to_datetime(clean_df['Date'])
clean_df['Adj Close'] = clean_df['Adj Close'].astype(float)
clean_df
# Out:
# C:\Users\kylem\AppData\Local\Temp\ipykernel_1076\4117434001.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Date'] = pd.to_datetime(clean_df['Date'])
# C:\Users\kylem\AppData\Local\Temp\ipykernel_1076\4117434001.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Adj Close'] = clean_df['Adj Close'].astype(float)
#       Name       Date        Open        High         Low       Close  \
# 0     AMZN 2018-07-30   91.366501   91.474998   88.301003   88.960999
# ...

# %%
print(clean_df['Name'].unique())
# Out:
# ['AMZN' 'META' 'NVDA' 'MSFT' 'GOOG' 'NFLX' 'AAPL']

# %%
#finding the data of pre and post meta name change for all FAANG stocks

#Amazon
amazon = clean_df.loc[clean_df["Name"] == 'AMZN']
amzn_pre = amazon.loc[amazon['Date'] < '2021-08-28']
amzn_post = amazon.loc[amazon['Date'] > '2021-08-28']

#Facebook
facebook = clean_df.loc[clean_df["Name"] == 'META']
fb_df = facebook.loc[facebook['Date'] < '2021-08-28']
meta_df = facebook.loc[facebook['Date'] > '2021-08-28']

#Nvidia
nvidia = clean_df.loc[clean_df["Name"] == 'NVDA']
nvda_pre = nvidia.loc[nvidia['Date'] < '2021-08-28']
nvda_post = nvidia.loc[nvidia['Date'] > '2021-08-28']

#Microsoft
microsoft = clean_df.loc[clean_df["Name"] == 'MSFT']
msft_pre = microsoft.loc[microsoft['Date'] < '2021-08-28']
msft_post = microsoft.loc[microsoft['Date'] > '2021-08-28']

#Google
google = clean_df.loc[clean_df["Name"] == 'GOOG']
goog_pre = google.loc[google['Date'] < '2021-08-28']
goog_post = google.loc[google['Date'] > '2021-08-28']

#Netflix
netflix = clean_df.loc[clean_df["Name"] == 'NFLX']
nflx_pre = netflix.loc[netflix['Date'] < '2021-08-28']
nflx_post = netflix.loc[netflix['Date'] > '2021-08-28']

#Apple
apple = clean_df.loc[clean_df["Name"] == 'AAPL']
aapl_pre = apple.loc[apple['Date'] < '2021-08-28']
aapl_post = apple.loc[apple['Date'] > '2021-08-28']

# %%
#change = pd.to_datetime(8/28/2021)
facebook = clean_df.loc[clean_df["Name"] == 'META']
fb_df = facebook.loc[facebook['Date'] < '2021-08-28']
meta_df = facebook.loc[facebook['Date'] > '2021-08-28']
meta_df
# Out:
#       Name       Date        Open        High         Low       Close  \
# 2036  META 2021-08-30  372.559998   381.48999  370.519989  380.660004
# 2037  META 2021-08-31  379.950012   382.76001  378.799988  379.380005
# 2038  META 2021-09-01  379.589996  384.329987  378.809998  382.049988
# 2039  META 2021-09-02       381.5      381.75  374.059998  375.279999
# 2040  META 2021-09-03      374.75  377.160004  373.109985   376.26001
# ...    ...        ...         ...         ...         ...         ...
# 2512  META 2023-07-24  295.779999  297.519989  288.299988  291.609985
# 2513  META 2023-07-25  295.190002  298.299988  291.859985  294.470001
# 2514  META 2023-07-26  301.190002  301.769989  291.899994  298.570007
# 2515  META 2023-07-27  325.119995  325.350006  309.839996  311.709991
# 2516  META 2023-07-28  316.880005  326.200012      314.25  325.480011
#
#        Adj Close    Volume
# 2036  380.660004  13547300
# 2037  379.380005  12345400
# 2038  382.049988  11567200
# ...

# %%
fb_df
# Out:
#       Name       Date        Open        High         Low       Close  \
# 1259  META 2018-07-30  175.300003  175.300003  166.559998  171.059998
# 1260  META 2018-07-31  170.669998  174.240005         170  172.580002
# 1261  META 2018-08-01  173.929993  175.080002  170.899994  171.649994
# 1262  META 2018-08-02  170.679993  176.789993  170.270004  176.369995
# 1263  META 2018-08-03  177.690002  178.850006  176.149994  177.779999
# ...    ...        ...         ...         ...         ...         ...
# 2031  META 2021-08-23  359.440002  365.690002  359.100006  363.350006
# 2032  META 2021-08-24  363.660004  367.959991  361.839996   365.51001
# 2033  META 2021-08-25  365.600006  370.859985  365.399994  368.390015
# 2034  META 2021-08-26  368.380005  369.440002  364.130005  364.380005
# 2035  META 2021-08-27  365.100006   373.73999  364.079987  372.630005
#
#        Adj Close    Volume
# 1259  171.059998  65280800
# 1260  172.580002  40356500
# 1261  171.649994  34042100
# ...

# %%
fb_1m = fb_df.loc[fb_df['Date']> '2021-07-28']
x_axis = fb_1m['Date']
y_axis= fb_1m['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Facebook')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
meta_1m = meta_df.loc[meta_df['Date']< '2021-09-28']
x_axis = meta_1m['Date']
y_axis= meta_1m['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.tight_layout()
plt.title('Meta')
plt.xlabel('Date')
plt.xticks(rotation = 45)
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
amzn_pre_1m = amzn_pre.loc[amzn_pre['Date']> '2021-07-28']
x_axis = amzn_pre_1m ['Date']
y_axis= amzn_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Amazon Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
amzn_post_1m = amzn_post.loc[amzn_post['Date']< '2021-09-28']
x_axis = amzn_post_1m ['Date']
y_axis= amzn_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.title('Amazon Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
aapl_pre_1m = aapl_pre.loc[aapl_pre['Date']> '2021-07-28']
x_axis = aapl_pre_1m ['Date']
y_axis= aapl_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Apple Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
aapl_post_1m = aapl_post.loc[aapl_post['Date']< '2021-09-28']
x_axis = aapl_post_1m ['Date']
y_axis= aapl_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.title('Apple Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nvda_pre_1m = nvda_pre.loc[nvda_pre['Date']> '2021-07-28']
x_axis = nvda_pre_1m ['Date']
y_axis= nvda_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Nvidia Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nvda_post_1m = nvda_post.loc[nvda_post['Date']< '2021-09-28']
x_axis = nvda_post_1m ['Date']
y_axis= nvda_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.title('Nvidia Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
msft_pre_1m = msft_pre.loc[msft_pre['Date']> '2021-07-28']
x_axis = msft_pre_1m ['Date']
y_axis= msft_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Microsoft Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
msft_post_1m = msft_post.loc[msft_post['Date']< '2021-09-28']
x_axis = msft_post_1m ['Date']
y_axis= msft_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.title('Microsoft Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
goog_pre_1m = goog_pre.loc[goog_pre['Date']> '2021-07-28']
x_axis = goog_pre_1m ['Date']
y_axis= goog_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Google Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
goog_post_1m = goog_post.loc[goog_post['Date']< '2021-09-28']
x_axis = goog_post_1m ['Date']
y_axis= goog_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.title('Google Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nflx_pre_1m = nflx_pre.loc[nflx_pre['Date']> '2021-07-28']
x_axis = nflx_pre_1m ['Date']
y_axis= nflx_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('Netflix Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nflx_post_1m = nflx_post.loc[nflx_post['Date']< '2021-09-28']
x_axis = nflx_post_1m ['Date']
y_axis= nflx_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis,y_axis, color='blue')
plt.xticks(rotation = 45)
plt.title('Netflix Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
goog_pre_1m = goog_pre.loc[goog_pre['Date']> '2021-07-28']
x_axis = goog_pre_1m ['Date']
y_axis_g = goog_pre_1m ['Adj Close']

msft_pre_1m = msft_pre.loc[msft_pre['Date']> '2021-07-28']
y_axis_m = msft_pre_1m ['Adj Close']


nvda_pre_1m = nvda_pre.loc[nvda_pre['Date']> '2021-07-28']
y_axis_n= nvda_pre_1m ['Adj Close']

amzn_pre_1m = amzn_pre.loc[amzn_pre['Date']> '2021-07-28']
y_axis_a= amzn_pre_1m ['Adj Close']

aapl_pre_1m = aapl_pre.loc[aapl_pre['Date']> '2021-07-28']
y_axis_aa= aapl_pre_1m ['Adj Close']

nflx_pre_1m = nflx_pre.loc[nflx_pre['Date']> '2021-07-28']
y_axis_nf= nflx_pre_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis, y_axis_m, label = 'Microsoft')
plt.plot(x_axis, y_axis_g, label = 'Google')
plt.plot(x_axis, y_axis_n, label = 'Nvidia')
plt.plot(x_axis, y_axis_a, label = 'Amazon')
plt.plot(x_axis, y_axis_aa, label = 'Apple')
plt.plot(x_axis, y_axis_nf, label = 'Netflix')
plt.legend()
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('FAANG Pre')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
goog_post_1m = goog_post.loc[goog_post['Date']< '2021-09-28']
x_axis = goog_post_1m ['Date']
y_axis_g = goog_post_1m ['Adj Close']

nsft_post_1m = msft_post.loc[msft_post['Date']< '2021-09-28']
y_axis_m = msft_post_1m ['Adj Close']

nvda_post_1m = nvda_post.loc[nvda_post['Date']< '2021-09-28']
y_axis_n= nvda_post_1m ['Adj Close']

amzn_post_1m = amzn_post.loc[amzn_post['Date']< '2021-09-28']
y_axis_a= amzn_post_1m ['Adj Close']

aapl_post_1m = aapl_post.loc[aapl_post['Date']< '2021-09-28']
y_axis_aa= aapl_post_1m ['Adj Close']

nflx_post_1m = nflx_post.loc[nflx_post['Date']< '2021-09-28']
y_axis_nf= nflx_post_1m ['Adj Close']

fig6, ax6 = plt.subplots()
plt.plot(x_axis, y_axis_m, label = 'Microsoft')
plt.plot(x_axis, y_axis_g, label = 'Google')
plt.plot(x_axis, y_axis_n, label = 'Nvidia')
plt.plot(x_axis, y_axis_a, label = 'Amazon')
plt.plot(x_axis, y_axis_aa, label = 'Apple')
plt.plot(x_axis, y_axis_nf, label = 'Netflix')
plt.legend()
plt.xticks(rotation = 45)
plt.tight_layout()
plt.title('MAANG Post')
plt.xlabel('Date')
plt.ylabel('Price')
fig6.set_tight_layout(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
